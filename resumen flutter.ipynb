# %% [markdown]
# <a href="https://colab.research.google.com/github/kalethgarcia76/primera-clase-Psicologia-del-dise-o/blob/main/resumen%20flutter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El material de "Flutter Apprentice: Desarrollo de Apps Multiplataforma" ofrece una visión integral sobre cómo construir aplicaciones profesionales desde cero utilizando el toolkit Flutter de Google y el lenguaje de programación Dart
# .
# A continuación se presenta un resumen de sus pilares y etapas principales:
# Fundamentos Multiplataforma: Explica cómo Flutter permite crear aplicaciones para iOS, Android, la Web y sistemas de escritorio a partir de una única base de código
# .
# Rendimiento Nativo y Arquitectura de Widgets: A diferencia de otros marcos que dependen de capas nativas del sistema operativo, Flutter utiliza su propio motor de renderizado para dibujar la interfaz de usuario con alto rendimiento
# . Todo en la interfaz está compuesto por widgets adaptables a sistemas de diseño como Material Design para Android o Cupertino para iOS
# .
# Productividad en el Desarrollo: Destaca herramientas esenciales como Hot Reload, la cual permite visualizar los cambios en el código en tiempo real dentro del emulador o dispositivo sin perder el estado actual de la aplicación
# .
# Estructura en Capas: Detalla la arquitectura del framework organizada en tres niveles: la capa de Framework en Dart (widgets e interfaz), el motor (Engine) en C++ (gráficos y renderizado) y el integrador de plataforma (Embedder)
# .
# Navegación y Datos: Aborda el flujo de trabajo completo para aplicaciones reales, incluyendo la navegación declarativa entre pantallas, el manejo de peticiones de red, la persistencia local de datos y la conexión con bases de datos en la nube
# .
# Calidad y Publicación: Revisa la importancia de realizar pruebas unitarias y de widgets para evitar errores, cubriendo finalmente el proceso paso a paso para publicar las aplicaciones en la App Store de Apple y Google Play Store
