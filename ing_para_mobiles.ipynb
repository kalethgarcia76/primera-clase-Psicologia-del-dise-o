# %% [markdown]
# <a href="https://colab.research.google.com/github/kalethgarcia76/primera-clase-Psicologia-del-dise-o/blob/main/ing_para_mobiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El video y recurso de Ingeniería Web Moderna presenta una hoja de ruta para transformar el desarrollo de aplicaciones web desde un enfoque empírico o caótico hacia una disciplina de ingeniería rigurosa y estructurada
# .
# Sus pilares principales incluyen:
# Procesos y Metodologías: Adopción de marcos como el proceso WebHelix Aumentado
# , el prototipado estratégico de UI
# , la agilidad aplicada al diseño incremental de bases de datos
#  y métodos de pruebas integradas y TDD
# .
# Arquitectura e Integración: Aplicación de procesos centrados en modelos (MAP)
# , diseño de Sistemas Orientados a Servicios (SOSS / SOA)
# , la integración de datos heterogéneos mediante mediadores
#  y la evolución hacia entornos Web 2.0 y clientes móviles
# .
# Gestión de Proyectos y Operación: Estrategias para gestionar audiencias globales, seguridad y múltiples partes interesadas
# , además de considerar aspectos clave de outsourcing
#  y despliegue basado en componentes
