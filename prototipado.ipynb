# %% [markdown]
# <a href="https://colab.research.google.com/github/kalethgarcia76/primera-clase-Psicologia-del-dise-o/blob/main/prototipado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **error de programar primero **, arreglar el codigo al final cuesta mas que arreglarlo al principio ,dura menos tiempo si se arregla a tiempo que al final
# **pruebas temprana**
# son las ideas que se dan a temprano tiempo ya que uno puede dibujar y mostrar que se a echo con tiempo y no al final
# **error con papel**
# es un producto que detecta los diseños que se usan ya que es la forma mas barata de corregir por que si no cuesta mas dinero al momento de arreglarlo
# **metododos**
# pruebas del primer clic la probabilidad sube un 85% de errores y correccion
# prueba de arbol evalua la calidad
# saben como empezar
# es intituivo el inicio
# es logica la estructura
# **pasos para mejorar**
# definir metas claras
# prototipo
# reclutar
# iterar
# arreglar en absoluto cilencio ya que hay estan los datos que maneja el usuario
# y nos les llamo la atencion y tambien que es lo que no esta en correcto funcionamiento o animacion.
# tambien ahorra tiempo, dinero, y lagrimas en el proximo proyecto.
# tambien hay tacticas de experiencia de usuarios.
# **fase diseño**
# facil y rapido en un trazo en el papel
# **fase de desarrollo**
# requiere rescribir codigo y perder horas de trabajo
# **fase de lanzamiento**
# daño a la calificacion rechazo de los usuarios restauracion total
# **necesidades del usuario**
# **validacion temprana**
# **suposiciones del equipo**
# **El prototipo**
# es una simulacion temprana y economica diseñada exclusiva
# **baja fidelidad**
# rapido y desechable
# **media fidelidad**
# interativo enfoque en la estructura
# **alta fidelidad **
#
# **costo cero**
# **animacion manual **
#
#
#  1.definir las metas
#  2.elegir fidelidad
#  3.reclutar
#  4.ejecutar
