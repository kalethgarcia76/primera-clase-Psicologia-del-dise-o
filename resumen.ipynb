# %% [markdown]
# <a href="https://colab.research.google.com/github/kalethgarcia76/primera-clase-Psicologia-del-dise-o/blob/main/resumen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# limitaciones del dispositivo , antes era un procesador 16 bits bajo ancho de banda tienen conexiones son poco fiables y procesasan mayoria de bajos recursos ,adoptando un enfoque sistematico desarrollo de ad-hoc es un proceso reactivo ya que tiene una un proceso de diciplina y tiene fases clave de proceso 1. analisis 2. diseño 3. implementacion hay que saber que es lo que va usar los usuarios y para que lo van a utilizar  y tienen las claves del equipo de pruebas la red tiene que ser de buena calidad y estable para que no tengan fallos las aplicaciones
